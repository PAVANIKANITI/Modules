# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-24 16:54:33--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   120MB/s    in 0.6s
#
# 2023-05-24 16:54:35 (120 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3984 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26597  1611.04353v2  We show that the algorithm to extract diverse ...    cs
# 4858   1606.01540v1  OpenAI Gym is a toolkit for reinforcement lear...    cs
# 6796   1706.02582v1  t-distributed Stochastic Neighborhood Embeddin...    cs
# 659    1608.04374v2  In this paper, a geometric framework for neura...  stat
# 20879  1704.05569v1  Extracting geographical tags from webpages is ...    cs
# ...             ...                                                ...   ...
# 22583  1701.07926v3  Consider a left-truncated right-censored survi...  stat
# 37005  1603.01488v1  The study of cellular signalling pathways and ...    cs
# 4765    1312.2710v1  High-speed, accuracy, meticulousness and quick...    cs
# 21649   1301.2724v2  Expectation Propagation (EP) provides a framew...  stat
# 10274   1102.1465v6  Prediction markets are used in real life to pr...  stat
#
#                                                    title  year  \
# 26597      Herding Generalizes Diverse M -Best Solutions  2016
# 4858                                          OpenAI Gym  2016
# 6796                     Clustering with t-SNE, provably  2017
# 659    A Geometric Framework for Convolutional Neural...  2016
# 20879  Using Contexts and Constraints for Improved Ge...  2017
# ...                                                  ...   ...
# 22583  Boosting hazard regression with time-varying c...  2017
# 37005  A knowledge representation meta-model for rule...  2016
# 4765   Improving circuit miniaturization and its effi...  2013
# 21649  Perturbative Corrections for Approximate Infer...  2013
# 10274  An Introduction to Artificial Prediction Marke...  2011
#
#                                                 keywords
# 26597  [algorithm, solutions, conditional, procedure,...
# 4858   [reinforcement, collection, benchmark, interfa...
# 6796   [distributed, stochastic, neighborhood, embedd...
# 659    [geometric, framework, framework, structure, u...
# 20879  [extracting, geographical, motivated, applicat...
# ...                                                  ...
# 22583  [truncated, evolution, covariates, functional,...
# 37005  [signalling, deregulation, extremely, processe...
# 4765   [meticulousness, necessities, efficient, elect...
# 21649  [expectation, propagation, framework, approxim...
# 10274  [prediction, presidential, elections, mathemat...
#
# [5187 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26597    [algorithm, solutions, conditional, procedure,...
# 4858     [reinforcement, collection, benchmark, interfa...
# 6796     [distributed, stochastic, neighborhood, embedd...
# 659      [geometric, framework, framework, structure, u...
# 20879    [extracting, geographical, motivated, applicat...
#                                ...
# 8065     [likelihood, graphical, challenges, computatio...
# 10104    [multisensory, estimation, sensorimotor, atten...
# 7756     [investigate, initialization, architecture, ac...
# 35887    [effectiveness, dissimilarity, collaborative, ...
# 11770    [introduction, analytics, treatment, informati...
# Name: keywords, Length: 6484, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 9121 words.
# Out of those 4767 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9f1f289d-8063-4d09-b845-c0eefb0b15cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f1f289d-8063-4d09-b845-c0eefb0b15cd")) {                    Plotly.newPlot(                        "9f1f289d-8063-4d09-b845-c0eefb0b15cd",                        [{"x":["implausible","solutions","conditional","generalizes","assumptions","demonstrate","experiments","procedure","generalization","properties","alternatives","constraints","segmentation","dynamical","hypotheses","algorithm","deterministic","collection","algorithms","reinforcement","decisions","components","discusses","performance","interface","benchmark","effectiveness","stochastic","optimization","topological","neighborhood","rigorously","technique","structures","connection","foundations","separated","embedding","clustering","byproduct","illustrate","parameter","distributed","precisely","numerical","understood","particular","visualization","mathematical","structure","coordinate","gradients","functions","calculated","convolutional","component","underlying","geometric","framework","described","extraction","extracting","empirical","application","preliminary","geographical","difficult","available","integrated","knowledge","challenging","precision","enforcement","programming","investigations","motivated","construction","defective","measurements","constitute","disagreements","reference","responsible","selection","validation","randomized","mechanisms","efficient","simulation","predictions","validated","transparent","including","important","discriminative","correlation","information","activation","discriminate","occlusion","explanations","visualizing","visualizations","measuring","resolution","answering","understand","captioning","desirable","applications","contained","regularized","equivalently","derivatives","expressed","guarantees","continuous","establishing","relatively","stability","inference","arbitrary","approximations","convergence","graphical","excellent","variables","favorably","propagation","approximate","estimates","theoretically","detection","environment","especially","navigation","development","contributes","attributed","introducing","definition","abstraction","bottleneck","distinctions","achievement","essential","recognition","emphasize","intelligence","overnight","processing","dramatically","representations","discussed","frameworks","frontiers","operation","advantages","perception","challenges","artificial","landscape","autonomous","unfortunately","regardless","different","principled","classical","omnidirectional","outperforms","techniques","classification","architectures","processed","geometrical","positions","distortions","similarly","evaluation","competitively","embeddings","resources","languages","tokenization","requiring","approaches","alternative","adjacency","connectome","exploratory","semiparametric","introduce","representation","biologically","elucidates","resulting","introduced","comparative","cooccurence","operators"],"y":[5,179,104,31,65,614,656,137,134,251,27,170,224,27,23,927,49,76,668,129,67,127,33,987,38,237,276,140,370,18,25,12,285,158,48,13,12,127,153,4,77,140,128,26,100,27,318,36,63,367,31,50,240,33,432,122,118,71,594,75,167,78,174,278,51,9,169,337,70,414,330,96,5,129,9,58,88,2,57,18,2,71,11,172,62,32,59,450,82,88,45,10,270,418,116,93,803,48,10,32,14,12,9,36,120,64,90,22,37,469,20,45,2,14,45,68,119,12,79,43,245,107,44,126,58,35,147,29,92,124,96,48,382,143,153,37,167,12,15,61,37,27,15,7,5,83,458,17,112,3,344,20,268,81,28,1,47,98,55,132,164,11,55,43,13,805,31,126,2,302,409,574,126,22,18,31,12,16,318,5,83,81,115,4,58,479,108,5,0,11,2,387,396,11,0,185,142,33,0,57],"type":"bar"},{"x":["implausible","solutions","conditional","generalizes","assumptions","demonstrate", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4767,), (4767, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7424826522744795

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>Enhancing</span> <span style=''>QPNs</span> <span style=''>for</span> <span style=''>Trade</span> <span style=''>off</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>Resolution</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>Qualitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>abstractions</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>belief</span> <span style=''>networks</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>drawbacks</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style=''>networks</span> <span style=''>is</span> <span style=''>their</span> <span style=''>coarse</span> <span style=''>level</span> <span style=''>of</span> <span style=''>detail</span> <span style=''>which</span> <span style=''>may</span> <span style=''>lead</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unresolved</span> <span style=''>trade</span> <span style=''>offs</span> <span style=''>during</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>enhanced</span> <span style='background-color:rgba(0, 255, 0, 0.41176470588235303);'>formalism</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>a</span> <span style=''>finer</span> <span style=''>level</span> <span style=''>of</span> <span style=''>detail</span> <span style=''>An</span> <span style=''>enhanced</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>network</span> <span style=''>differs</span> <span style=''>from</span> <span style=''>a</span> <span style=''>regular</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style=''>network</span> <span style=''>in</span> <span style=''>that</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>distinguishes</span> <span style=''>between</span> <span style=''>strong</span> <span style=''>and</span> <span style=''>weak</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influences</span> <span style=''>Enhanced</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>purely</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style=''>in</span> <span style=''>nature</span> <span style=''>as</span> <span style=''>regular</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>qualitative</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>yet</span> <span style=''>allow</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>resolving</span> <span style=''>trade</span> <span style=''>offs</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exponential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Screening</span> <br/><br/><span style=''>In</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exponential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Screening</span> <span style=''>(gES)</span> <span style=''>linearly</span> <span style=''>combines</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>graphs</span> <span style=''>and</span> <span style=''>balances</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>error</span> <span style=''>and</span> <span style=''>sparsity</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparable</span> <span style=''>to</span> <span style=''>that</span> <span style=''>of</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>single</span> <span style=''>graph</span> <span style=''>chosen</span> <span style=''>by</span> <span style=''>an</span> <span style=''>oracle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigated</span> <span style=''>using</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>and</span> <span style=''>real</span> <span style=''>datasets</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>with</span> <span style=''>some</span> <span style=''>state</span> <span style=''>of</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Surprising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Robustness</span> <span style=''>of</span> <span style=''>HMMs</span> <br/><br/><span style=''>Suppose</span> <span style=''>that</span> <span style=''>we</span> <span style=''>are</span> <span style=''>given</span> <span style=''>a</span> <span style=''>time</span> <span style=''>series</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.7037037037037037);'>consecutive</span> <span style=''>samples</span> <span style=''>are</span> <span style=''>believed</span> <span style=''>to</span> <span style=''>come</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>source</span> <span style=''>that</span> <span style=''>the</span> <span style=''>source</span> <span style=''>changes</span> <span style=''>from</span> <span style=''>time</span> <span style=''>to</span> <span style=''>time</span> <span style=''>and</span> <span style=''>that</span> <span style=''>the</span> <span style=''>total</span> <span style=''>number</span> <span style=''>of</span> <span style=''>sources</span> <span style=''>is</span> <span style=''>fixed</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>is</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sources</span> <span style=''>A</span> <span style=''>standard</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style=''>model</span> <span style=''>the</span> <span style=''>data</span> <span style=''>as</span> <span style=''>a</span> <span style=''>hidden</span> <span style=''>Markov</span> <span style=''>model</span> <span style=''>(HMM)</span> <span style=''>However</span> <span style=''>since</span> <span style=''>the</span> <span style=''>data</span> <span style=''>often</span> <span style=''>lacks</span> <span style=''>the</span> <span style=''>Markov</span> <span style=''>or</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationarity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>an</span> <span style=''>HMM</span> <span style=''>one</span> <span style=''>can</span> <span style=''>ask</span> <span style=''>whether</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>still</span> <span style=''>suitable</span> <span style=''>or</span> <span style=''>perhaps</span> <span style=''>another</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>required</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.48854961832061067);'>likelihood</span> <span style=''>HMM</span> <span style='background-color:rgba(255, 0, 0, 0.7456647398843931);'>estimator</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style=''>source</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>in</span> <span style=''>a</span> <span style=''>much</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>SIGNet</span> <span style=''>Scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embeddings</span> <span style=''>for</span> <span style=''>Signed</span> <span style=''>Networks</span> <br/><br/><span style=''>Recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successes</span> <span style=''>in</span> <span style=''>word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>and</span> <span style=''>document</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>for</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>to</span> <span style=''>use</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>for</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>edge</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>node</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>Such</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>largely</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>finding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>for</span> <span style=''>unsigned</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>are</span> <span style=''>unable</span> <span style=''>to</span> <span style=''>discover</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>that</span> <span style=''>respect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polarities</span> <span style=''>inherent</span> <span style=''>in</span> <span style=''>edges</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>SIGNet</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>method</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>signed</span> <span style=''>networks</span> <span style=''>Our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>aims</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style=''>model</span> <span style=''>the</span> <span style=''>social</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>implicit</span> <span style=''>in</span> <span style=''>signed</span> <span style=''>networks</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>of</span> <span style=''>social</span> <span style=''>balance</span> <span style=''>theory</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>builds</span> <span style=''>upon</span> <span style=''>the</span> <span style='background-color:rgb ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10827824992130941)
# 	segmentation (0.07050676739062008)
# 	architecture (0.08655964746616304)
# 	knowledge (0.13031161473087818)
# 	experimental (0.1391249606547057)
# 	different (0.2533836953100409)
# 	detection (0.12023921938936104)
# 	information (0.2527541706011961)
# 	convolutional (0.1359773371104816)
# 	recognition (0.14416115832546428)
#
# Some Statistics words are:
# 	optimization (0.19601990049751244)
# 	estimation (0.17512437810945275)
# 	variables (0.13880597014925372)
# 	statistical (0.15074626865671642)
# 	algorithm (0.39054726368159204)
# 	theoretical (0.15124378109452735)
# 	dimensional (0.18109452736318407)
# 	distribution (0.1900497512437811)
# 	inference (0.19502487562189055)
# 	regression (0.1855721393034826)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5fecd3b3-2e99-4036-9a4f-fc798b31b5c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fecd3b3-2e99-4036-9a4f-fc798b31b5c4")) {                    Plotly.newPlot(                        "5fecd3b3-2e99-4036-9a4f-fc798b31b5c4",                        [{"x":["implausible","solutions","conditional","generalizes","assumptions","demonstrate","experiments","procedure","generalization","properties","alternatives","constraints","segmentation","dynamical","hypotheses","algorithm","deterministic","collection","algorithms","reinforcement","decisions","components","discusses","performance","interface","benchmark","effectiveness","stochastic","optimization","topological","neighborhood","rigorously","technique","structures","connection","foundations","separated","embedding","clustering","byproduct","illustrate","parameter","distributed","precisely","numerical","understood","particular","visualization","mathematical","structure","coordinate","gradients","functions","calculated","convolutional","component","underlying","geometric","framework","described","extraction","extracting","empirical","application","preliminary","geographical","difficult","available","integrated","knowledge","challenging","precision","enforcement","programming","investigations","motivated","construction","defective","measurements","constitute","disagreements","reference","responsible","selection","validation","randomized","mechanisms","efficient","simulation","predictions","validated","transparent","including","important","discriminative","correlation","information","activation","discriminate","occlusion","explanations","visualizing","visualizations","measuring","resolution","answering","understand","captioning","desirable","applications","contained","regularized","equivalently","derivatives","expressed","guarantees","continuous","establishing","relatively","stability","inference","arbitrary","approximations","convergence","graphical","excellent","variables","favorably","propagation","approximate","estimates","theoretically","detection","environment","especially","navigation","development","contributes","attributed","introducing","definition","abstraction","bottleneck","distinctions","achievement","essential","recognition","emphasize","intelligence","overnight","processing","dramatically","representations","discussed","frameworks","frontiers","operation","advantages","perception","challenges","artificial","landscape","autonomous","unfortunately","regardless","different","principled","classical","omnidirectional","outperforms","techniques","classification","architectures","processed","geometrical","positions","distortions","similarly","evaluation","competitively","embeddings","resources","languages","tokenization","requiring","approaches","alternative","adjacency","connectome","exploratory","semiparametric","introduce","representation","biologically","elucidates","resulting","introduced","comparative","cooccurence","operators","occurrence","dimension","denoising","applicable","literature","restoration","specifically","refinement","preserves","satisfies","improvement","distributions","spontaneous","associated","discovering","generating","equivalent","equivalence","experimental","simulated","discovery","highlight","differential","analytical","feedforward","arbitrarily","expressions","geometries","parameters","unconstrained","enhancing","equations","diffusion","advection","probability","counterexample","insufficient","justifying","rectified","computational","rectifiers","nonlinearities","challenge","surpassing","initialization","traditional","rectifier","parametric","extremely","considers","overfitting","investigate","particularly","significantly","averaging","published","exponenti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	connectome
# 	elucidates
# 	cooccurence
# 	advection
# 	cytometry
# 	nonparanormal
# 	emphmulti
# 	searchlight
# 	inappropriately
# 	chronological
# 	precautions
# 	mcallester
# 	identifiability
# 	replicates
# 	unintentionally
# 	subroutines
# 	faithfulness
# 	dendrogram
# 	nonparametrically
# 	statistician
# Some words which never appear in Statistics papers:
# 	enforcement
# 	defective
# 	overnight
# 	omnidirectional
# 	tokenization
# 	spontaneous
# 	rectifiers
# 	surpassing
# 	homophily
# 	sociological
# 	ethnicity
# 	substrings
# 	entertainments
# 	employment
# 	autonomously
# 	suspicious
# 	orienteering
# 	cityscapes
# 	connectionist
# 	multisets

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 2.736951583326491e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7016191210485736
